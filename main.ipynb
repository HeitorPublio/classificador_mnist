# %%
from keras import datasets, layers, models
from keras.preprocessing import image
import numpy as np

(x_train, y_train), (x_test, y_test) = datasets.mnist.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=5)

test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f"Acurácia no teste: {test_acc:.2f}")
# Out:
# c:\Users\heito\OneDrive\Documentos\GitHub\classificador_mnist\venv_class\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8766 - loss: 0.4396
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9662 - loss: 0.1168
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9757 - loss: 0.0818
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9846 - loss: 0.0546
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9887 - loss: 0.0406
# 313/313 - 1s - 2ms/step - accuracy: 0.9754 - loss: 0.0775
# Acurácia no teste: 0.98

# %%
import numpy as np
import matplotlib.pyplot as plt

img = x_test[7]        
label = y_test[7]      

plt.imshow(img, cmap="gray")
plt.title(f"Rótulo verdadeiro: {label}")
plt.show()

img = np.expand_dims(img, axis=0)

pred = model.predict(img)
predicted_class = np.argmax(pred)

print(f"Modelo previu: {predicted_class}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Modelo previu: 9
